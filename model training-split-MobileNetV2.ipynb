# %%
from keras.applications.mobilenet_v2 import MobileNetV2 
from keras.applications.mobilenet import MobileNet
from keras.applications.densenet import DenseNet169
from keras.applications.resnet50 import ResNet50
from keras.applications.nasnet import NASNetMobile, NASNetLarge
from keras.applications.xception import Xception
from keras.applications.inception_v3 import InceptionV3
from keras.preprocessing.image import ImageDataGenerator
from keras.preprocessing.image import img_to_array
from sklearn.preprocessing import LabelBinarizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from keras.models import Sequential, Model, load_model
from keras.layers import Input, Dense, Dropout
from keras.optimizers import Adam, SGD, Adagrad, Adadelta
from keras import backend as K
from imutils import paths
import matplotlib.pyplot as plt
import numpy as np
import argparse
import imutils
import random
import pickle
import cv2
import os
import math

# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %%
# DATASET_PATH = r"G:\landmarks_of_melbourne_sml"
DATASET_PATH = r"E:\dataset15"
TESTSET_PATH = r"E:\testset15-s"

# initialize the number of epochs to train for, initial learning rate, batch size, and image dimensions
EPOCHS = 15
INIT_LR = 0.001
BS = 8
LABEL_NUM = 15
READING_BS = 1000

# image dimension may need to change according to the model spec
IMAGE_DIMS =  (224, 224, 3)

# initialize the data and labels
data = []
labels = []

data_test =[]
labels_test=[]

# grab the image paths and randomly shuffle them
imagePaths = sorted(list(paths.list_images(DATASET_PATH)))
random.Random(881278).shuffle(imagePaths)

testPaths = sorted(list(paths.list_images(TESTSET_PATH)))

# %%
# loop over the test images
for testPath in testPaths:
    # load the image, pre-process it, and store it in the data_test list
    assert os.path.isfile(testPath)
    image = cv2.imread(testPath)
    image = cv2.resize(image, (IMAGE_DIMS[1], IMAGE_DIMS[0]))
    image = img_to_array(image)
    data_test.append(image)

    # extract the class label from the image path and update the labels_test list
    label = testPath.split(os.path.sep)[-2]
    labels_test.append(label)
    
# scale the raw pixel intensities to the range [0, 1]
data_test = np.array(data_test, dtype="float") / 255.0
labels_test = np.array(labels_test)
print("test data matrix: {:.2f}MB".format(data_test.nbytes / (1024 * 1000.0)))

# binarize the labels
lb = LabelBinarizer()
labels_test = lb.fit_transform(labels_test)
# Out:
# test data matrix: 498.62MB

# %%
# create a custom input layer that accepts images of shape IMAGE_DIMS
input_tensor = Input(shape=IMAGE_DIMS)

# grab the Keras built-in model for transfer learning
base_model = MobileNetV2(
        include_top=False,
        weights='imagenet',
        input_tensor=input_tensor,
        input_shape=IMAGE_DIMS,
        pooling='avg')

# original model is trained on different dataset with different number of classes
# so we need to append our own output layer
output_tensor = Dense(LABEL_NUM, activation='softmax')(base_model.output)

model = Model(inputs=input_tensor, outputs=output_tensor)

model.compile(Adam(lr=1e-4), loss="categorical_crossentropy", metrics=['accuracy', 'top_k_categorical_accuracy'])
# Out:
# WARNING:tensorflow:From C:\Users\PC-user\AppData\Local\conda\conda\envs\tensorflow-gpu\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %%
chunk_paths = [imagePaths[i:i + READING_BS] for i in range(0, len(imagePaths), READING_BS)]
for chunk_path in chunk_paths:
    # loop over the each chuck
    data = []
    labels = []
    for imagePath in chunk_path:
        # load the image, pre-process it, and store it in the data list
        assert os.path.isfile(imagePath)
        image = cv2.imread(imagePath)
        image = cv2.resize(image, (IMAGE_DIMS[1], IMAGE_DIMS[0]))
        image = img_to_array(image)
        data.append(image)

        # extract the class label from the image path and update the labels list
        label = imagePath.split(os.path.sep)[-2]
        labels.append(label)
    
    # construct the image generator for data augmentation
    # aug = ImageDataGenerator(rotation_range=25, width_shift_range=0.1, height_shift_range=0.1, 
    #                          shear_range=0.2, zoom_range=0.2, horizontal_flip=True)
    aug = ImageDataGenerator(width_shift_range=0.1, height_shift_range=0.1)
    
    # scale the raw pixel intensities to the range [0, 1]
    data = np.array(data, dtype="float") / 255.0
    labels = np.array(labels)
    print("training data matrix: {:.2f}MB".format(data.nbytes / (1024 * 1000.0)))

    # binarize the labels
    lb = LabelBinarizer()
    labels = lb.fit_transform(labels)
    
    h = model.fit_generator(
        aug.flow(data, labels, batch_size=BS),
        validation_data=(data_test, labels_test),
        steps_per_epoch=math.ceil(len(data)/BS),
        epochs=EPOCHS, verbose=1)
# Out:
# training data matrix: 1176.00MB
# WARNING:tensorflow:From C:\Users\PC-user\AppData\Local\conda\conda\envs\tensorflow-gpu\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/15
# 125/125 [==============================] - 19s 152ms/step - loss: 1.2557 - acc: 0.6550 - top_k_categorical_accuracy: 0.8700 - val_loss: 0.6755 - val_acc: 0.8184 - val_top_k_categorical_accuracy: 0.9693
# Epoch 2/15
# 125/125 [==============================] - 10s 82ms/step - loss: 0.3372 - acc: 0.9200 - top_k_categorical_accuracy: 0.9930 - val_loss: 0.3804 - val_acc: 0.8986 - val_top_k_categorical_accuracy: 0.9906
# Epoch 3/15
# 125/125 [==============================] - 10s 82ms/step - loss: 0.1642 - acc: 0.9650 - top_k_categorical_accuracy: 0.9980 - val_loss: 0.3259 - val_acc: 0.9151 - val_top_k_categorical_accuracy: 0.9906
# Epoch 4/15
# 125/125 [==============================] - 10s 82ms/step - loss: 0.1016 - acc: 0.9770 - top_k_categorical_accuracy: 0.9990 - val_loss: 0.2482 - val_acc: 0.9269 - val_top_k_categorical_accuracy: 0.9929
# Epoch 5/15
# 125/125 [==============================] - 10s 82ms/step - loss: 0.0847 - acc: 0.9820 - top_k_categorical_accuracy: 1.0000 - val_loss: 0.2704 - val_acc: 0.9127 - val_top_k_categorical_accuracy: 0.9929
# Epoch 6/15
# 125/125 [==============================] - 10s 82ms/step - loss: 0.0795 - acc: 0.9840 - top_k_categorical_accuracy: 0.9980 - val_loss: 0.2899 - val_acc: 0.9057 - val_top_k_categorical_accuracy: 0.9882
# Epoch 7/15
# 125/125 [==============================] - 10s 82ms/step - loss: 0.0361 - acc: 0.9930 - top_k_categorical_accuracy: 1.0000 - val_loss: 0.2160 - val_acc: 0.9363 - val_top_k_categorical_accuracy: 0.9953
# Epoch 8/15
# 125/125 [==============================] - 10s 82ms/step - loss: 0.0287 - acc: 0.9950 - top_k_categorical_accuracy: 1.0000 - val_loss: 0.2104 - val_acc: 0.9410 - val_top_k_categorical_accuracy: 0.9929
# Epoch 9/15
# 125/125 [==============================] - 10s 82ms/step - loss: 0.0292 - acc: 0.9970 - top_k_categorical_accuracy: 1.0000 - val_loss: 0.1984 - val_acc: 0.9363 - val_top_k_categorical_accuracy: 0.9953
# Epoch 10/15
# 125/125 [==============================] - 10s 82ms/step - loss: 0.0390 - acc: 0.9890 - top_k_categorical_accuracy: 0.9990 - val_loss: 0.2944 - val_acc: 0.9080 - val_top_k_categorical_accuracy: 0.9906
# Epoch 11/15
# 125/125 [==============================] - 10s 82ms/step - loss: 0.0396 - acc: 0.9900 - top_k_categorical_accuracy: 0.9990 - val_loss: 0.4338 - val_acc: 0.8750 - val_top_k_categorical_accuracy: 0.9835
# Epoch 12/15
# 125/125 [==============================] - 10s 83ms/step - loss: 0.0209 - acc: 0.9950 - top_k_categorical_accuracy: 1.0000 - val_loss: 0.2758 - val_acc: 0.9127 - val_top_k_categorical_accuracy: 0.9953
# Epoch 13/15
# 125/125 [==============================] - 10s 82ms/step - loss: 0.0248 - acc: 0.9980 - top_k_categorical_accuracy: 1.0000 - val_loss: 0.3162 - val_acc: 0.8986 - val_top_k_categorical_accuracy: 0.9929
# Epoch 14/15
# 125/125 [==============================] - 10s 82ms/step - loss: 0.0312 - acc: 0.9900 - top_k_categorical_accuracy: 1.0000 - val_loss: 0.2571 - val_acc: 0.9222 - val_top_k_categorical_accuracy: 0.9929
# Epoch 15/15
# 125/125 [==============================] - 10s 82ms/step - loss: 0.0218 - acc: 0.9970 - top_k_categorical_accuracy: 1.0000 - val_loss: 0.2538 - val_acc: 0.9340 - val_top_k_categorical_accuracy: 0.9906
# training data matrix: 1176.00MB
# Epoch 1/15
# 125/125 [==============================] - 10s 84ms/step - loss: 0.2688 - acc: 0.9300 - top_k_categorical_accuracy: 0.9900 - val_loss: 0.3333 - val_acc: 0.9080 - val_top_k_categorical_accuracy: 0.9906
# Epoch 2/15
# 125/125 [==============================] - 10s 82ms/step - loss: 0.1245 - acc: 0.9630 - top_k_categorical_accuracy: 0.9980 - val_loss: 0.3759 - val_acc: 0.8892 - val_top_k_categorical_accuracy: 0.9882
# Epoch 3/15
# 125/125 [==============================] - 10s 83ms/step - loss: 0.0522 - acc: 0.9840 - top_k_categorical_accuracy: 0.9990 - val_loss: 0.3890 - val_acc: 0.8821 - val_top_k_categorical_accuracy: 0.9929
# Epoch 4/15
# 125/125 [==============================] - 10s 82ms/step - loss: 0.0421 - acc: 0.9880 - top_k_categorical_accuracy: 1.0000 - val_loss: 0.2486 - val_acc: 0.9269 - val_top_k_categorical_accuracy: 0.9976
# Epoch 5/15
# 125/125 [==============================] - 10s 83ms/step - loss: 0.0379 - acc: 0.9890 - top_k_categorical_accuracy: 1.0000 - val_loss: 0.2025 - val_acc: 0.9340 - val_top_k_categorical_accuracy: 0.9953
# Epoch 6/15
# 125/125 [==============================] - 10s 83ms/step - loss: 0.0487 - acc: 0.9840 - top_k_categorical_accuracy: 1.0000 - val_loss: 0.2721 - val_acc: 0.9269 - val_top_k_categorical_accuracy: 0.9929
# Epoch 7/15
# 125/125 [==============================] - 10s 83ms/step - loss: 0.0421 - acc: 0.9870 - top_k_categorical_accuracy: 1.0000 - val_loss: 0.3549 - val_acc: 0.8986 - val_top_k_categorical_accuracy: 0.9882
# Epoch 8/15
# 125/125 [==============================] - 10s 82ms/step - loss: 0.0375 - acc: 0.9880 - top_k_categorical_accuracy: 1.0000 - val_loss: 0.4916 - val_acc: 0.8868 - val_top_k_categorical_accuracy: 0.9906
# Epoch 9/15
# 125/125 [==============================] - 10s 82ms/step - loss: 0.0295 - acc: 0.9930 - top_k_categorical_accuracy: 1.0000 - val_loss: 0.4242 - val_acc: 0.9009 - val_top_k_categorical_accuracy: 0.9906
# Epoch 10/15
# 125/125 [==============================] - 10s 83ms/step - loss: 0.0333 - acc: 0.9860 - top_k_categorical_accuracy: 1.0000 - val_loss: 0.3204 - val_acc: 0.9033 - val_top_k_categorical_accuracy: 0.9929
# Epoch 11/15
# 125/125 [==============================] - 10s 81ms/step - loss: 0.0140 - acc: 0.9970 - top_k_categorical_accuracy: 1.0000 - val_loss: 0.2740 - val_acc: 0.9222 - val_top_k_categorical_accuracy: 0.9906
# Epoch 12/15
# 125/125 [==============================] - 10s 81ms/step - loss: 0.0243 - acc: 0.9930 - top_k_categorical_accuracy: 1.0000 - val_loss: 0.3813 - val_acc: 0.9104 - val_top_k_categorical_accuracy: 0.9811
# Epoch 13/15
# 125/125 [==============================] - 10s 81ms/step - loss: 0.0165 - acc: 0.9970 - top_k_categorical_accuracy: 1.0000 - val_loss: 0.3123 - val_acc: 0.9198 - val_top_k_categorical_accuracy: 0.9882
# Epoch 14/15
# 125/125 [==============================] - 10s 81ms/step - loss: 0.0271 - acc: 0.9920 - top_k_categorical_accuracy: 0.9990 - val_loss: 0.2523 - val_acc: 0.9387 - val_top_k_categorical_accuracy: 0.9906
# Epoch 15/15
# 125/125 [==============================] - 10s 81ms/step - loss: 0.0099 - acc: 0.9980 - top_k_categorical_accuracy: 1.0000 - val_loss: 0.2376 - val_acc: 0.9269 - val_top_k_categorical_accuracy: 0.9929
# training data matrix: 1176.00MB
# Epoch 1/15
# 125/125 [==============================] - 10s 82ms/step - loss: 0.2005 - acc: 0.9460 - top_k_categorical_accuracy: 0.9950 - val_loss: 0.4244 - val_acc: 0.8892 - val_top_k_categorical_accuracy: 0.9858
# Epoch 2/15
# 125/125 [==============================] - 10s 81ms/step - loss: 0.1524 - acc: 0.9530 - top_k_categorical_accuracy: 0.9950 - val_loss: 0.8713 - val_acc: 0.8113 - val_top_k_categorical_accuracy: 0.9835
# Epoch 3/15
# 125/125 [==============================] - 10s 81ms/step - loss: 0.0342 - acc: 0.9900 - top_k_categorical_accuracy: 1.0000 - val_loss: 0.5681 - val_acc: 0.8844 - val_top_k_categorical_accuracy: 0.9858
# Epoch 4/15
# 125/125 [==============================] - 10s 82ms/step - loss: 0.0337 - acc: 0.9890 - top_k_categorical_accuracy: 1.0000 - val_loss: 0.4091 - val_acc: 0.9104 - val_top_k_categorical_accuracy: 0.9858
# Epoch 5/15
# 125/125 [==============================] - 10s 83ms/step - loss: 0.0359 - acc: 0.9890 - top_k_categorical_accuracy: 1.0000 - val_loss: 0.4740 - val_acc: 0.8962 - val_top_k_categorical_accuracy: 0.9882
# Epoch 6/15
# 125/125 [==============================] - 10s 82ms/step - loss: 0.0151 - acc: 0.9970 - top_k_categorical_accuracy: 1.0000 - val_loss: 0.3545 - val_acc: 0.9127 - val_top_k_categorical_accuracy: 0.9882
# Epoch 7/15
# 125/125 [==============================] - 10s 83ms/step - loss: 0.0242 - acc: 0.9930 - top_k_categorical_accuracy: 1.0000 - val_loss: 0.2907 - val_acc: 0.9175 - val_top_k_categorical_accuracy: 0.9906
# Epoch 8/15
# 125/125 [==============================] - 10s 82ms/step - loss: 0.0209 - acc: 0.9960 - top_k_categorical_accuracy: 1.0000 - val_loss: 0.2752 - val_acc: 0.9269 - val_top_k_categorical_accuracy: 0.9929
# Epoch 9/15
# 125/125 [==============================] - 10s 82ms/step - loss: 0.0250 - acc: 0.9920 - top_k_categorical_accuracy: 0.9990 - val_loss: 0.3632 - val_acc: 0.9222 - val_top_k_categorical_accuracy: 0.9811
# Epoch 10/15
# 125/125 [==============================] - 10s 82ms/step - loss: 0.0097 - acc: 0.9980 - top_k_categorical_accuracy: 1.0000 - val_loss: 0.3729 - val_acc: 0.9104 - val_top_k_categorical_accuracy: 0.9882
# Epoch 11/15
# 125/125 [==============================] - 10s 82ms/step - loss: 0.0204 - acc: 0.9950 - top_k_categorical_accuracy: 1.0000 - val_loss: 0.3289 - val_acc: 0.9198 - val_top_k_categorical_accuracy: 0.9858
# Epoch 12/15
# 125/125 [==============================] - 10s 82ms/step - loss: 0.0353 - acc: 0.9920 - top_k_categorical_accuracy: 0.9990 - val_loss: 0.5019 - val_acc: 0.8703 - val_top_k_categorical_accuracy: 0.9906
# Epoch 13/15
# 125/125 [==============================] - 10s 82ms/step - loss: 0.0260 - acc: 0.9910 - top_k_categorical_accuracy: 1.0000 - val_loss: 0.4528 - val_acc: 0.8892 - val_top_k_categorical_accuracy: 0.9811
# Epoch 14/15
# 125/125 [==============================] - 10s 82ms/step - loss: 0.0379 - acc: 0.9900 - top_k_categorical_accuracy: 1.0000 - val_loss: 0.8716 - val_acc: 0.8467 - val_top_k_categorical_accuracy: 0.9528
# Epoch 15/15
# 125/125 [==============================] - 10s 82ms/step - loss: 0.0308 - acc: 0.9900 - top_k_categorical_accuracy: 1.0000 - val_loss: 0.9212 - val_acc: 0.8278 - val_top_k_categorical_accuracy: 0.9670
# training data matrix: 1176.00MB
# Epoch 1/15
# 125/125 [==============================] - 10s 83ms/step - loss: 0.2162 - acc: 0.9520 - top_k_categorical_accuracy: 0.9890 - val_loss: 0.4017 - val_acc: 0.9245 - val_top_k_categorical_accuracy: 0.9858
# Epoch 2/15
# 125/125 [==============================] - 10s 82ms/step - loss: 0.0454 - acc: 0.9890 - top_k_categorical_accuracy: 0.9990 - val_loss: 0.5919 - val_acc: 0.8844 - val_top_k_categorical_accuracy: 0.9717
# Epoch 3/15
# 125/125 [==============================] - 10s 82ms/step - loss: 0.0500 - acc: 0.9870 - top_k_categorical_accuracy: 1.0000 - val_loss: 0.5796 - val_acc: 0.9057 - val_top_k_categorical_accuracy: 0.9693
# Epoch 4/15
# 125/125 [==============================] - 10s 82ms/step - loss: 0.0589 - acc: 0.9770 - top_k_categorical_accuracy: 1.0000 - val_loss: 0.2756 - val_acc: 0.9292 - val_top_k_categorical_accuracy: 0.9906
# Epoch 5/15
# 125/125 [==============================] - 10s 82ms/step - loss: 0.0377 - acc: 0.9860 - top_k_categorical_accuracy: 1.0000 - val_loss: 0.5043 - val_acc: 0.9009 - val_top_k_categorical_accuracy: 0.9764
# Epoch 6/15
# 125/125 [==============================] - 10s 82ms/step - loss: 0.0231 - acc: 0.9930 - top_k_categorical_accuracy: 1.0000 - val_loss: 0.3361 - val_acc: 0.9245 - val_top_k_categorical_accuracy: 0.9835
# Epoch 7/15
# 125/125 [==============================] - 10s 82ms/step - loss: 0.0143 - acc: 0.9950 - top_k_categorical_accuracy: 1.0000 - val_loss: 0.3210 - val_acc: 0.9269 - val_top_k_categorical_accuracy: 0.9811
# Epoch 8/15
# 125/125 [==============================] - 10s 82ms/step - loss: 0.0228 - acc: 0.9920 - top_k_categorical_accuracy: 1.0000 - val_loss: 0.4410 - val_acc: 0.9104 - val_top_k_categorical_accuracy: 0.9835
# Epoch 9/15
# 125/125 [==============================] - 10s 83ms/step - loss: 0.0207 - acc: 0.9930 - top_k_categorical_accuracy: 1.0000 - val_loss: 0.3205 - val_acc: 0.9316 - val_top_k_categorical_accuracy: 0.9858
# Epoch 10/15
# 125/125 [==============================] - 10s 83ms/step - loss: 0.0130 - acc: 0.9950 - top_k_categorical_accuracy: 1.0000 - val_loss: 0.3080 - val_acc: 0.9363 - val_top_k_categorical_accuracy: 0.9858
# Epoch 11/15
# 125/125 [==============================] - 10s 83ms/step - loss: 0.0230 - acc: 0.9960 - top_k_categorical_accuracy: 0.9990 - val_loss: 0.3671 - val_acc: 0.9175 - val_top_k_categorical_accuracy: 0.9929
# Epoch 12/15
# 125/125 [==============================] - 10s 83ms/step - loss: 0.0213 - acc: 0.9940 - top_k_categorical_accuracy: 1.0000 - val_loss: 0.4746 - val_acc: 0.8892 - val_top_k_categorical_accuracy: 0.9858
# Epoch 13/15
# 125/125 [==============================] - 10s 83ms/step - loss: 0.0361 - acc: 0.9890 - top_k_categorical_accuracy: 1.0000 - val_loss: 0.2594 - val_acc: 0.9528 - val_top_k_categorical_accuracy: 0.9929
# Epoch 6/15
# 125/125 [==============================] - 10s 84ms/step - loss: 0.0263 - acc: 0.9900 - top_k_categorical_accuracy: 1.0000 - val_loss: 0.2437 - val_acc: 0.9434 - val_top_k_categorical_accuracy: 0.9953
# Epoch 7/15
# 125/125 [==============================] - 10s 82ms/step - loss: 0.0221 - acc: 0.9930 - top_k_categorical_accuracy: 1.0000 - val_loss: 0.3210 - val_acc: 0.9269 - val_top_k_categorical_accuracy: 0.9929
# Epoch 8/15
# 125/125 [==============================] - 10s 80ms/step - loss: 0.0131 - acc: 0.9970 - top_k_categorical_accuracy: 1.0000 - val_loss: 0.2969 - val_acc: 0.9458 - val_top_k_categorical_accuracy: 0.9906
# Epoch 9/15
# 125/125 [==============================] - 11s 84ms/step - loss: 0.0085 - acc: 0.9970 - top_k_categorical_accuracy: 1.0000 - val_loss: 0.2926 - val_acc: 0.9434 - val_top_k_categorical_accuracy: 0.9929
# Epoch 10/15
# 125/125 [==============================] - 11s 85ms/step - loss: 0.0084 - acc: 0.9980 - top_k_categorical_accuracy: 1.0000 - val_loss: 0.2837 - val_acc: 0.9458 - val_top_k_categorical_accuracy: 0.9906
# Epoch 11/15
# 125/125 [==============================] - 10s 83ms/step - loss: 0.0129 - acc: 0.9950 - top_k_categorical_accuracy: 1.0000 - val_loss: 0.2092 - val_acc: 0.9623 - val_top_k_categorical_accuracy: 0.9929
# Epoch 12/15
# 125/125 [==============================] - 10s 84ms/step - loss: 0.0111 - acc: 0.9960 - top_k_categorical_accuracy: 1.0000 - val_loss: 0.2285 - val_acc: 0.9505 - val_top_k_categorical_accuracy: 0.9929
# Epoch 13/15
# 125/125 [==============================] - 10s 82ms/step - loss: 0.0053 - acc: 0.9980 - top_k_categorical_accuracy: 1.0000 - val_loss: 0.1971 - val_acc: 0.9693 - val_top_k_categorical_accuracy: 0.9929
# Epoch 14/15
# 125/125 [==============================] - 10s 80ms/step - loss: 0.0231 - acc: 0.9930 - top_k_categorical_accuracy: 1.0000 - val_loss: 0.1895 - val_acc: 0.9623 - val_top_k_categorical_accuracy: 0.9929
# Epoch 15/15
# 125/125 [==============================] - 10s 81ms/step - loss: 0.0136 - acc: 0.9970 - top_k_categorical_accuracy: 1.0000 - val_loss: 0.3372 - val_acc: 0.9387 - val_top_k_categorical_accuracy: 0.9835
# training data matrix: 880.82MB
# Epoch 1/15
# 94/94 [==============================] - 9s 93ms/step - loss: 0.2040 - acc: 0.9434 - top_k_categorical_accuracy: 0.9947 - val_loss: 0.9785 - val_acc: 0.8066 - val_top_k_categorical_accuracy: 0.9764
# Epoch 2/15
# 94/94 [==============================] - 8s 86ms/step - loss: 0.0908 - acc: 0.9747 - top_k_categorical_accuracy: 0.9987 - val_loss: 1.4299 - val_acc: 0.7429 - val_top_k_categorical_accuracy: 0.9788
# Epoch 3/15
# 94/94 [==============================] - 8s 86ms/step - loss: 0.0713 - acc: 0.9734 - top_k_categorical_accuracy: 1.0000 - val_loss: 0.9069 - val_acc: 0.8184 - val_top_k_categorical_accuracy: 0.9670
# Epoch 4/15
# 94/94 [==============================] - 8s 87ms/step - loss: 0.0284 - acc: 0.9907 - top_k_categorical_accuracy: 1.0000 - val_loss: 1.0505 - val_acc: 0.7807 - val_top_k_categorical_accuracy: 0.9788
# Epoch 5/15
# 94/94 [==============================] - 8s 86ms/step - loss: 0.0364 - acc: 0.9920 - top_k_categorical_accuracy: 1.0000 - val_loss: 0.9350 - val_acc: 0.8231 - val_top_k_categorical_accuracy: 0.9882
# Epoch 6/15
# 94/94 [==============================] - 8s 87ms/step - loss: 0.0340 - acc: 0.9880 - top_k_categorical_accuracy: 1.0000 - val_loss: 0.8877 - val_acc: 0.8066 - val_top_k_categorical_accuracy: 0.9882
# Epoch 7/15
# 94/94 [==============================] - 8s 86ms/step - loss: 0.0119 - acc: 0.9960 - top_k_categorical_accuracy: 1.0000 - val_loss: 0.3679 - val_acc: 0.9033 - val_top_k_categorical_accuracy: 0.9906
# Epoch 8/15
# 94/94 [==============================] - 8s 86ms/step - loss: 0.0064 - acc: 0.9987 - top_k_categorical_accuracy: 1.0000 - val_loss: 0.4449 - val_acc: 0.8915 - val_top_k_categorical_accuracy: 0.9882
# Epoch 9/15
# 94/94 [==============================] - 8s 86ms/step - loss: 0.0120 - acc: 0.9973 - top_k_categorical_accuracy: 1.0000 - val_loss: 0.4965 - val_acc: 0.8939 - val_top_k_categorical_accuracy: 0.9906
# Epoch 10/15
# 94/94 [==============================] - 8s 86ms/step - loss: 0.0183 - acc: 0.9947 - top_k_categorical_accuracy: 1.0000 - val_loss: 0.6421 - val_acc: 0.8750 - val_top_k_categorical_accuracy: 0.9929
# Epoch 11/15
# 94/94 [==============================] - 8s 86ms/step - loss: 0.0129 - acc: 0.9973 - top_k_categorical_accuracy: 1.0000 - val_loss: 0.5372 - val_acc: 0.8962 - val_top_k_categorical_accuracy: 0.9929
# Epoch 12/15
# 94/94 [==============================] - 8s 86ms/step - loss: 0.0145 - acc: 0.9947 - top_k_categorical_accuracy: 1.0000 - val_loss: 0.3499 - val_acc: 0.9340 - val_top_k_categorical_accuracy: 0.9906
# Epoch 13/15
# 94/94 [==============================] - 8s 86ms/step - loss: 0.0182 - acc: 0.9934 - top_k_categorical_accuracy: 1.0000 - val_loss: 0.3284 - val_acc: 0.9458 - val_top_k_categorical_accuracy: 0.9882
# Epoch 14/15
# 94/94 [==============================] - 8s 86ms/step - loss: 0.0098 - acc: 0.9979 - top_k_categorical_accuracy: 1.0000 - val_loss: 0.3132 - val_acc: 0.9340 - val_top_k_categorical_accuracy: 0.9882
# Epoch 15/15
# 94/94 [==============================] - 8s 86ms/step - loss: 0.0131 - acc: 0.9947 - top_k_categorical_accuracy: 1.0000 - val_loss: 0.3140 - val_acc: 0.9363 - val_top_k_categorical_accuracy: 0.9882

# %%
# save the model to disk
model.save(r"E:\models\224\MobileNetV2")

# %%
# save the label binarizer to disk
f = open(r"E:\models\lb-dataset15-m", "wb")
f.write(pickle.dumps(lb))
f.close()
