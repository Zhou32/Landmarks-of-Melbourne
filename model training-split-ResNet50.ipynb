# %%
from keras.applications.mobilenet_v2 import MobileNetV2 
from keras.applications.mobilenet import MobileNet
from keras.applications.densenet import DenseNet169
from keras.applications.resnet50 import ResNet50
from keras.applications.nasnet import NASNetMobile, NASNetLarge
from keras.applications.xception import Xception
from keras.applications.inception_v3 import InceptionV3
from keras.preprocessing.image import ImageDataGenerator
from keras.preprocessing.image import img_to_array
from sklearn.preprocessing import LabelBinarizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from keras.models import Sequential, Model, load_model
from keras.layers import Input, Dense, Dropout
from keras.optimizers import Adam, SGD, Adagrad, Adadelta
from keras import backend as K
from imutils import paths
import matplotlib.pyplot as plt
import numpy as np
import argparse
import imutils
import random
import pickle
import cv2
import os
import math

# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %%
# DATASET_PATH = r"G:\landmarks_of_melbourne_sml"
DATASET_PATH = r"E:\dataset15"
TESTSET_PATH = r"E:\testset15"

# initialize the number of epochs to train for, initial learning rate, batch size, and image dimensions
EPOCHS = 15
INIT_LR = 0.001
BS = 8
LABEL_NUM = 15
READING_BS = 1000

# image dimension may need to change according to the model spec
IMAGE_DIMS =  (224, 224, 3)
IMAGE_DIMS =  (299, 299, 3)

# initialize the data and labels
data = []
labels = []

data_test =[]
labels_test=[]

# grab the image paths and randomly shuffle them
imagePaths = sorted(list(paths.list_images(DATASET_PATH)))
random.Random(881278).shuffle(imagePaths)

testPaths = sorted(list(paths.list_images(TESTSET_PATH)))

# %%
# loop over the test images
for testPath in testPaths:
    # load the image, pre-process it, and store it in the data_test list
    assert os.path.isfile(testPath)
    image = cv2.imread(testPath)
    image = cv2.resize(image, (IMAGE_DIMS[1], IMAGE_DIMS[0]))
    image = img_to_array(image)
    data_test.append(image)

    # extract the class label from the image path and update the labels_test list
    label = testPath.split(os.path.sep)[-2]
    labels_test.append(label)
    
# scale the raw pixel intensities to the range [0, 1]
data_test = np.array(data_test, dtype="float") / 255.0
labels_test = np.array(labels_test)
print("test data matrix: {:.2f}MB".format(data_test.nbytes / (1024 * 1000.0)))

# binarize the labels
lb = LabelBinarizer()
labels_test = lb.fit_transform(labels_test)
# Out:
# test data matrix: 1565.22MB

# %%
# create a custom input layer that accepts images of shape IMAGE_DIMS
input_tensor = Input(shape=IMAGE_DIMS)

# grab the Keras built-in model for transfer learning
base_model = ResNet50(
        include_top=False,
        weights='imagenet',
        input_tensor=input_tensor,
        input_shape=IMAGE_DIMS,
        pooling='avg')

# original model is trained on different dataset with different number of classes
# so we need to append our own output layer
output_tensor = Dense(LABEL_NUM, activation='softmax')(base_model.output)

model = Model(inputs=input_tensor, outputs=output_tensor)

model.compile(Adam(lr=1e-4), loss="categorical_crossentropy", metrics=['accuracy', 'top_k_categorical_accuracy'])
# Out:
# WARNING:tensorflow:From C:\Users\PC-user\AppData\Local\conda\conda\envs\tensorflow-gpu\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# Downloading data from https://github.com/fchollet/deep-learning-models/releases/download/v0.2/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94658560/94653016 [==============================] - 29s 0us/step

# %%
chunk_paths = [imagePaths[i:i + READING_BS] for i in range(0, len(imagePaths), READING_BS)]
for chunk_path in chunk_paths:
    # loop over the each chuck
    data = []
    labels = []
    for imagePath in chunk_path:
        # load the image, pre-process it, and store it in the data list
        assert os.path.isfile(imagePath)
        image = cv2.imread(imagePath)
        image = cv2.resize(image, (IMAGE_DIMS[1], IMAGE_DIMS[0]))
        image = img_to_array(image)
        data.append(image)

        # extract the class label from the image path and update the labels list
        label = imagePath.split(os.path.sep)[-2]
        labels.append(label)
    
    # construct the image generator for data augmentation
    # aug = ImageDataGenerator(rotation_range=25, width_shift_range=0.1, height_shift_range=0.1, 
    #                          shear_range=0.2, zoom_range=0.2, horizontal_flip=True)
    aug = ImageDataGenerator(width_shift_range=0.1, height_shift_range=0.1)
    
    # scale the raw pixel intensities to the range [0, 1]
    data = np.array(data, dtype="float") / 255.0
    labels = np.array(labels)
    print("training data matrix: {:.2f}MB".format(data.nbytes / (1024 * 1000.0)))

    # binarize the labels
    lb = LabelBinarizer()
    labels = lb.fit_transform(labels)
    
    h = model.fit_generator(
        aug.flow(data, labels, batch_size=BS),
        validation_data=(data_test, labels_test),
        steps_per_epoch=math.ceil(len(data)/BS),
        epochs=EPOCHS, verbose=1)
# Out:
# training data matrix: 2095.34MB
# WARNING:tensorflow:From C:\Users\PC-user\AppData\Local\conda\conda\envs\tensorflow-gpu\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/15
# 125/125 [==============================] - 44s 351ms/step - loss: 0.7232 - acc: 0.7960 - top_k_categorical_accuracy: 0.9350 - val_loss: 0.2698 - val_acc: 0.9290 - val_top_k_categorical_accuracy: 0.9866
# Epoch 2/15
# 125/125 [==============================] - 30s 238ms/step - loss: 0.1066 - acc: 0.9770 - top_k_categorical_accuracy: 0.9990 - val_loss: 0.2523 - val_acc: 0.9465 - val_top_k_categorical_accuracy: 0.9906
# Epoch 3/15
# 125/125 [==============================] - 30s 240ms/step - loss: 0.0493 - acc: 0.9890 - top_k_categorical_accuracy: 1.0000 - val_loss: 0.3146 - val_acc: 0.9344 - val_top_k_categorical_accuracy: 0.9906
# Epoch 4/15
# 125/125 [==============================] - 30s 237ms/step - loss: 0.0361 - acc: 0.9950 - top_k_categorical_accuracy: 1.0000 - val_loss: 0.1614 - val_acc: 0.9665 - val_top_k_categorical_accuracy: 0.9866
# Epoch 5/15
# 125/125 [==============================] - 30s 240ms/step - loss: 0.0407 - acc: 0.9910 - top_k_categorical_accuracy: 1.0000 - val_loss: 0.3928 - val_acc: 0.9344 - val_top_k_categorical_accuracy: 0.9826
# Epoch 6/15
# 125/125 [==============================] - 30s 239ms/step - loss: 0.0493 - acc: 0.9890 - top_k_categorical_accuracy: 0.9990 - val_loss: 0.1995 - val_acc: 0.9465 - val_top_k_categorical_accuracy: 0.9906
# Epoch 7/15
# 125/125 [==============================] - 29s 236ms/step - loss: 0.0691 - acc: 0.9810 - top_k_categorical_accuracy: 1.0000 - val_loss: 0.2992 - val_acc: 0.9290 - val_top_k_categorical_accuracy: 0.9880
# Epoch 8/15
# 125/125 [==============================] - 30s 237ms/step - loss: 0.1509 - acc: 0.9530 - top_k_categorical_accuracy: 0.9980 - val_loss: 0.3239 - val_acc: 0.9090 - val_top_k_categorical_accuracy: 0.9893
# Epoch 9/15
# 125/125 [==============================] - 30s 240ms/step - loss: 0.0712 - acc: 0.9800 - top_k_categorical_accuracy: 0.9990 - val_loss: 0.4561 - val_acc: 0.9157 - val_top_k_categorical_accuracy: 0.9866
# Epoch 10/15
# 125/125 [==============================] - 30s 237ms/step - loss: 0.0196 - acc: 0.9950 - top_k_categorical_accuracy: 1.0000 - val_loss: 0.1826 - val_acc: 0.9531 - val_top_k_categorical_accuracy: 0.9920
# Epoch 11/15
# 125/125 [==============================] - 30s 237ms/step - loss: 0.0182 - acc: 0.9970 - top_k_categorical_accuracy: 1.0000 - val_loss: 0.1536 - val_acc: 0.9652 - val_top_k_categorical_accuracy: 0.9906
# Epoch 12/15
# 125/125 [==============================] - 30s 237ms/step - loss: 0.0115 - acc: 0.9960 - top_k_categorical_accuracy: 1.0000 - val_loss: 0.2003 - val_acc: 0.9505 - val_top_k_categorical_accuracy: 0.9893
# Epoch 13/15
# 125/125 [==============================] - 30s 239ms/step - loss: 0.0255 - acc: 0.9950 - top_k_categorical_accuracy: 0.9990 - val_loss: 0.2151 - val_acc: 0.9465 - val_top_k_categorical_accuracy: 0.9906
# Epoch 14/15
# 125/125 [==============================] - 30s 241ms/step - loss: 0.0041 - acc: 1.0000 - top_k_categorical_accuracy: 1.0000 - val_loss: 0.1361 - val_acc: 0.9746 - val_top_k_categorical_accuracy: 0.9920
# Epoch 15/15
# 125/125 [==============================] - 30s 244ms/step - loss: 0.0247 - acc: 0.9920 - top_k_categorical_accuracy: 1.0000 - val_loss: 0.2254 - val_acc: 0.9491 - val_top_k_categorical_accuracy: 0.9866
# training data matrix: 2095.34MB
# Epoch 1/15
# 125/125 [==============================] - 30s 240ms/step - loss: 0.3536 - acc: 0.8950 - top_k_categorical_accuracy: 0.9870 - val_loss: 1.2103 - val_acc: 0.7523 - val_top_k_categorical_accuracy: 0.9558
# Epoch 2/15
# 125/125 [==============================] - 30s 236ms/step - loss: 0.1453 - acc: 0.9590 - top_k_categorical_accuracy: 0.9980 - val_loss: 0.1338 - val_acc: 0.9585 - val_top_k_categorical_accuracy: 0.9960
# Epoch 3/15
# 125/125 [==============================] - 30s 239ms/step - loss: 0.0431 - acc: 0.9900 - top_k_categorical_accuracy: 1.0000 - val_loss: 0.0827 - val_acc: 0.9786 - val_top_k_categorical_accuracy: 0.9987
# Epoch 4/15
# 125/125 [==============================] - 29s 235ms/step - loss: 0.0176 - acc: 0.9960 - top_k_categorical_accuracy: 1.0000 - val_loss: 0.0843 - val_acc: 0.9759 - val_top_k_categorical_accuracy: 1.0000
# Epoch 5/15
# 125/125 [==============================] - 29s 236ms/step - loss: 0.0066 - acc: 1.0000 - top_k_categorical_accuracy: 1.0000 - val_loss: 0.0846 - val_acc: 0.9746 - val_top_k_categorical_accuracy: 0.9973
# Epoch 6/15
# 125/125 [==============================] - 29s 236ms/step - loss: 0.0099 - acc: 0.9990 - top_k_categorical_accuracy: 1.0000 - val_loss: 0.1063 - val_acc: 0.9719 - val_top_k_categorical_accuracy: 0.9960
# Epoch 7/15
# 125/125 [==============================] - 30s 238ms/step - loss: 0.0236 - acc: 0.9930 - top_k_categorical_accuracy: 1.0000 - val_loss: 0.2673 - val_acc: 0.9451 - val_top_k_categorical_accuracy: 0.9946
# Epoch 8/15
# 125/125 [==============================] - 29s 236ms/step - loss: 0.0276 - acc: 0.9910 - top_k_categorical_accuracy: 1.0000 - val_loss: 0.0917 - val_acc: 0.9705 - val_top_k_categorical_accuracy: 1.0000
# Epoch 9/15
# 125/125 [==============================] - 30s 240ms/step - loss: 0.0418 - acc: 0.9850 - top_k_categorical_accuracy: 1.0000 - val_loss: 0.4404 - val_acc: 0.9116 - val_top_k_categorical_accuracy: 0.9946
# Epoch 10/15
# 125/125 [==============================] - 30s 240ms/step - loss: 0.0358 - acc: 0.9860 - top_k_categorical_accuracy: 1.0000 - val_loss: 0.1196 - val_acc: 0.9665 - val_top_k_categorical_accuracy: 0.9987
# Epoch 11/15
# 125/125 [==============================] - 29s 236ms/step - loss: 0.0492 - acc: 0.9860 - top_k_categorical_accuracy: 1.0000 - val_loss: 0.4329 - val_acc: 0.8795 - val_top_k_categorical_accuracy: 0.9893
# Epoch 12/15
# 125/125 [==============================] - 30s 239ms/step - loss: 0.0550 - acc: 0.9830 - top_k_categorical_accuracy: 0.9990 - val_loss: 0.1270 - val_acc: 0.9598 - val_top_k_categorical_accuracy: 0.9960
# Epoch 13/15
# 125/125 [==============================] - 30s 238ms/step - loss: 0.0089 - acc: 0.9990 - top_k_categorical_accuracy: 1.0000 - val_loss: 0.0760 - val_acc: 0.9772 - val_top_k_categorical_accuracy: 1.0000
# Epoch 14/15
# 125/125 [==============================] - 30s 236ms/step - loss: 0.0024 - acc: 1.0000 - top_k_categorical_accuracy: 1.0000 - val_loss: 0.0702 - val_acc: 0.9786 - val_top_k_categorical_accuracy: 0.9987
# Epoch 15/15
# 125/125 [==============================] - 30s 237ms/step - loss: 0.0020 - acc: 1.0000 - top_k_categorical_accuracy: 1.0000 - val_loss: 0.0725 - val_acc: 0.9772 - val_top_k_categorical_accuracy: 0.9960
# training data matrix: 2095.34MB
# Epoch 1/15
# 125/125 [==============================] - 30s 238ms/step - loss: 0.2074 - acc: 0.9440 - top_k_categorical_accuracy: 0.9910 - val_loss: 0.4900 - val_acc: 0.8876 - val_top_k_categorical_accuracy: 0.9946
# Epoch 2/15
# 125/125 [==============================] - 30s 237ms/step - loss: 0.1125 - acc: 0.9710 - top_k_categorical_accuracy: 0.9980 - val_loss: 0.1663 - val_acc: 0.9639 - val_top_k_categorical_accuracy: 0.9973
# Epoch 3/15
# 125/125 [==============================] - 30s 237ms/step - loss: 0.0492 - acc: 0.9840 - top_k_categorical_accuracy: 1.0000 - val_loss: 0.1170 - val_acc: 0.9679 - val_top_k_categorical_accuracy: 0.9973
# Epoch 4/15
# 125/125 [==============================] - 30s 237ms/step - loss: 0.0581 - acc: 0.9840 - top_k_categorical_accuracy: 1.0000 - val_loss: 0.1148 - val_acc: 0.9705 - val_top_k_categorical_accuracy: 0.9973
# Epoch 5/15
# 125/125 [==============================] - 30s 237ms/step - loss: 0.0210 - acc: 0.9930 - top_k_categorical_accuracy: 1.0000 - val_loss: 0.0974 - val_acc: 0.9692 - val_top_k_categorical_accuracy: 0.9987
# Epoch 6/15
# 125/125 [==============================] - 30s 237ms/step - loss: 0.0270 - acc: 0.9930 - top_k_categorical_accuracy: 0.9990 - val_loss: 0.0590 - val_acc: 0.9826 - val_top_k_categorical_accuracy: 0.9987
# Epoch 7/15
# 125/125 [==============================] - 30s 236ms/step - loss: 0.0073 - acc: 1.0000 - top_k_categorical_accuracy: 1.0000 - val_loss: 0.0688 - val_acc: 0.9866 - val_top_k_categorical_accuracy: 0.9987
# Epoch 8/15
# 125/125 [==============================] - 29s 236ms/step - loss: 0.0028 - acc: 1.0000 - top_k_categorical_accuracy: 1.0000 - val_loss: 0.0629 - val_acc: 0.9853 - val_top_k_categorical_accuracy: 0.9987
# Epoch 9/15
# 125/125 [==============================] - 30s 237ms/step - loss: 0.0022 - acc: 1.0000 - top_k_categorical_accuracy: 1.0000 - val_loss: 0.0649 - val_acc: 0.9839 - val_top_k_categorical_accuracy: 0.9987
# Epoch 10/15
# 125/125 [==============================] - 30s 236ms/step - loss: 0.0048 - acc: 0.9990 - top_k_categorical_accuracy: 1.0000 - val_loss: 0.0630 - val_acc: 0.9866 - val_top_k_categorical_accuracy: 0.9973
# Epoch 11/15
# 125/125 [==============================] - 30s 237ms/step - loss: 0.0282 - acc: 0.9910 - top_k_categorical_accuracy: 1.0000 - val_loss: 0.2007 - val_acc: 0.9478 - val_top_k_categorical_accuracy: 0.9906
# Epoch 12/15
# 125/125 [==============================] - 30s 236ms/step - loss: 0.0327 - acc: 0.9890 - top_k_categorical_accuracy: 1.0000 - val_loss: 0.1313 - val_acc: 0.9531 - val_top_k_categorical_accuracy: 1.0000
# Epoch 13/15
# 125/125 [==============================] - 30s 240ms/step - loss: 0.0289 - acc: 0.9920 - top_k_categorical_accuracy: 0.9990 - val_loss: 0.6867 - val_acc: 0.8862 - val_top_k_categorical_accuracy: 0.9839
# Epoch 14/15
# 125/125 [==============================] - 30s 242ms/step - loss: 0.0254 - acc: 0.9920 - top_k_categorical_accuracy: 1.0000 - val_loss: 0.0978 - val_acc: 0.9759 - val_top_k_categorical_accuracy: 0.9987
# Epoch 15/15
# 125/125 [==============================] - 31s 245ms/step - loss: 0.0074 - acc: 1.0000 - top_k_categorical_accuracy: 1.0000 - val_loss: 0.1036 - val_acc: 0.9732 - val_top_k_categorical_accuracy: 1.0000
# training data matrix: 2095.34MB
# Epoch 1/15
# 125/125 [==============================] - 31s 245ms/step - loss: 0.1758 - acc: 0.9530 - top_k_categorical_accuracy: 0.9970 - val_loss: 0.1634 - val_acc: 0.9585 - val_top_k_categorical_accuracy: 0.9960
# Epoch 2/15
# 125/125 [==============================] - 30s 243ms/step - loss: 0.0670 - acc: 0.9800 - top_k_categorical_accuracy: 0.9990 - val_loss: 0.1562 - val_acc: 0.9545 - val_top_k_categorical_accuracy: 0.9920
# Epoch 3/15
# 125/125 [==============================] - 30s 238ms/step - loss: 0.0873 - acc: 0.9750 - top_k_categorical_accuracy: 1.0000 - val_loss: 0.1073 - val_acc: 0.9732 - val_top_k_categorical_accuracy: 1.0000
# Epoch 4/15
# 125/125 [==============================] - 30s 240ms/step - loss: 0.0454 - acc: 0.9860 - top_k_categorical_accuracy: 1.0000 - val_loss: 0.0998 - val_acc: 0.9732 - val_top_k_categorical_accuracy: 0.9946
# Epoch 5/15
# 125/125 [==============================] - 30s 244ms/step - loss: 0.0429 - acc: 0.9870 - top_k_categorical_accuracy: 0.9990 - val_loss: 0.1705 - val_acc: 0.9505 - val_top_k_categorical_accuracy: 0.9973
# Epoch 6/15
# 125/125 [==============================] - 30s 241ms/step - loss: 0.0450 - acc: 0.9900 - top_k_categorical_accuracy: 1.0000 - val_loss: 0.0439 - val_acc: 0.9853 - val_top_k_categorical_accuracy: 1.0000
# Epoch 7/15
# 125/125 [==============================] - 30s 240ms/step - loss: 0.0093 - acc: 0.9980 - top_k_categorical_accuracy: 1.0000 - val_loss: 0.0527 - val_acc: 0.9839 - val_top_k_categorical_accuracy: 1.0000
# Epoch 8/15
# 125/125 [==============================] - 31s 246ms/step - loss: 0.0086 - acc: 0.9970 - top_k_categorical_accuracy: 1.0000 - val_loss: 0.0668 - val_acc: 0.9826 - val_top_k_categorical_accuracy: 0.9973
# Epoch 9/15
# 125/125 [==============================] - 31s 250ms/step - loss: 0.0039 - acc: 0.9990 - top_k_categorical_accuracy: 1.0000 - val_loss: 0.0633 - val_acc: 0.9813 - val_top_k_categorical_accuracy: 0.9960
# Epoch 10/15
# 125/125 [==============================] - 31s 244ms/step - loss: 0.0163 - acc: 0.9940 - top_k_categorical_accuracy: 1.0000 - val_loss: 0.0771 - val_acc: 0.9772 - val_top_k_categorical_accuracy: 0.9987
# Epoch 11/15
# 125/125 [==============================] - 30s 244ms/step - loss: 0.0333 - acc: 0.9920 - top_k_categorical_accuracy: 1.0000 - val_loss: 0.0749 - val_acc: 0.9826 - val_top_k_categorical_accuracy: 0.9973
# Epoch 12/15
# 125/125 [==============================] - 31s 245ms/step - loss: 0.0102 - acc: 0.9980 - top_k_categorical_accuracy: 1.0000 - val_loss: 0.0533 - val_acc: 0.9839 - val_top_k_categorical_accuracy: 1.0000
# Epoch 13/15
# 125/125 [==============================] - 31s 245ms/step - loss: 0.0060 - acc: 0.9990 - top_k_categorical_accuracy: 1.0000 - val_loss: 0.1075 - val_acc: 0.9759 - val_top_k_categorical_accuracy: 0.9973
# Epoch 14/15
# 125/125 [==============================] - 30s 242ms/step - loss: 0.0024 - acc: 1.0000 - top_k_categorical_accuracy: 1.0000 - val_loss: 0.0527 - val_acc: 0.9866 - val_top_k_categorical_accuracy: 0.9973
# Epoch 15/15
# 125/125 [==============================] - 31s 245ms/step - loss: 0.0034 - acc: 1.0000 - top_k_categorical_accuracy: 1.0000 - val_loss: 0.0482 - val_acc: 0.9880 - val_top_k_categorical_accuracy: 0.9973
# training data matrix: 2095.34MB
# Epoch 1/15
# 125/125 [==============================] - 30s 243ms/step - loss: 0.1698 - acc: 0.9560 - top_k_categorical_accuracy: 0.9920 - val_loss: 0.5866 - val_acc: 0.8661 - val_top_k_categorical_accuracy: 0.9973
# Epoch 2/15
# 125/125 [==============================] - 30s 243ms/step - loss: 0.0745 - acc: 0.9790 - top_k_categorical_accuracy: 1.0000 - val_loss: 0.0791 - val_acc: 0.9759 - val_top_k_categorical_accuracy: 1.0000
# Epoch 3/15
# 125/125 [==============================] - 30s 241ms/step - loss: 0.0179 - acc: 0.9960 - top_k_categorical_accuracy: 1.0000 - val_loss: 0.1585 - val_acc: 0.9652 - val_top_k_categorical_accuracy: 1.0000
# Epoch 4/15
# 125/125 [==============================] - 30s 240ms/step - loss: 0.0226 - acc: 0.9950 - top_k_categorical_accuracy: 1.0000 - val_loss: 0.0794 - val_acc: 0.9839 - val_top_k_categorical_accuracy: 0.9987
# Epoch 5/15
# 125/125 [==============================] - 30s 240ms/step - loss: 0.0121 - acc: 0.9960 - top_k_categorical_accuracy: 1.0000 - val_loss: 0.2248 - val_acc: 0.9625 - val_top_k_categorical_accuracy: 0.9973
# Epoch 6/15
# 125/125 [==============================] - 30s 240ms/step - loss: 0.0123 - acc: 0.9950 - top_k_categorical_accuracy: 1.0000 - val_loss: 0.0632 - val_acc: 0.9853 - val_top_k_categorical_accuracy: 1.0000
# Epoch 7/15
# 125/125 [==============================] - 30s 241ms/step - loss: 0.0115 - acc: 0.9980 - top_k_categorical_accuracy: 1.0000 - val_loss: 0.0575 - val_acc: 0.9853 - val_top_k_categorical_accuracy: 1.0000
# Epoch 8/15
# 125/125 [==============================] - 30s 240ms/step - loss: 0.0383 - acc: 0.9870 - top_k_categorical_accuracy: 1.0000 - val_loss: 0.3140 - val_acc: 0.9157 - val_top_k_categorical_accuracy: 0.9933
# Epoch 9/15
# 125/125 [==============================] - 30s 240ms/step - loss: 0.0425 - acc: 0.9900 - top_k_categorical_accuracy: 0.9990 - val_loss: 0.0940 - val_acc: 0.9772 - val_top_k_categorical_accuracy: 0.9987
# Epoch 10/15
# 125/125 [==============================] - 30s 240ms/step - loss: 0.0103 - acc: 0.9980 - top_k_categorical_accuracy: 1.0000 - val_loss: 0.1089 - val_acc: 0.9799 - val_top_k_categorical_accuracy: 0.9987
# Epoch 11/15
# 125/125 [==============================] - 30s 241ms/step - loss: 0.0090 - acc: 0.9970 - top_k_categorical_accuracy: 1.0000 - val_loss: 0.0487 - val_acc: 0.9866 - val_top_k_categorical_accuracy: 1.0000
# Epoch 12/15
# 125/125 [==============================] - 30s 240ms/step - loss: 0.0070 - acc: 0.9970 - top_k_categorical_accuracy: 1.0000 - val_loss: 0.0590 - val_acc: 0.9853 - val_top_k_categorical_accuracy: 0.9987
# Epoch 13/15
# 125/125 [==============================] - 30s 240ms/step - loss: 0.0031 - acc: 0.9990 - top_k_categorical_accuracy: 1.0000 - val_loss: 0.0528 - val_acc: 0.9866 - val_top_k_categorical_accuracy: 1.0000
# Epoch 14/15
# 125/125 [==============================] - 30s 240ms/step - loss: 0.0013 - acc: 1.0000 - top_k_categorical_accuracy: 1.0000 - val_loss: 0.0484 - val_acc: 0.9920 - val_top_k_categorical_accuracy: 1.0000
# Epoch 15/15
# 125/125 [==============================] - 30s 240ms/step - loss: 0.0019 - acc: 1.0000 - top_k_categorical_accuracy: 1.0000 - val_loss: 0.0617 - val_acc: 0.9853 - val_top_k_categorical_accuracy: 0.9987
# training data matrix: 1569.41MB
# Epoch 1/15
# 94/94 [==============================] - 27s 290ms/step - loss: 0.1926 - acc: 0.9447 - top_k_categorical_accuracy: 0.9894 - val_loss: 0.2629 - val_acc: 0.9411 - val_top_k_categorical_accuracy: 0.9920
# Epoch 2/15
# 94/94 [==============================] - 24s 258ms/step - loss: 0.1115 - acc: 0.9641 - top_k_categorical_accuracy: 0.9973 - val_loss: 0.2817 - val_acc: 0.9384 - val_top_k_categorical_accuracy: 0.9960
# Epoch 3/15
# 94/94 [==============================] - 24s 258ms/step - loss: 0.0340 - acc: 0.9920 - top_k_categorical_accuracy: 1.0000 - val_loss: 0.2744 - val_acc: 0.9572 - val_top_k_categorical_accuracy: 0.9946
# Epoch 4/15
# 94/94 [==============================] - 24s 255ms/step - loss: 0.0175 - acc: 0.9947 - top_k_categorical_accuracy: 1.0000 - val_loss: 0.0575 - val_acc: 0.9893 - val_top_k_categorical_accuracy: 1.0000
# Epoch 5/15
# 94/94 [==============================] - 24s 256ms/step - loss: 0.0379 - acc: 0.9934 - top_k_categorical_accuracy: 1.0000 - val_loss: 0.1806 - val_acc: 0.9585 - val_top_k_categorical_accuracy: 1.0000
# Epoch 6/15
# 94/94 [==============================] - 24s 255ms/step - loss: 0.0190 - acc: 0.9947 - top_k_categorical_accuracy: 1.0000 - val_loss: 0.0750 - val_acc: 0.9759 - val_top_k_categorical_accuracy: 1.0000
# Epoch 7/15
# 94/94 [==============================] - 24s 256ms/step - loss: 0.0093 - acc: 1.0000 - top_k_categorical_accuracy: 1.0000 - val_loss: 0.0488 - val_acc: 0.9906 - val_top_k_categorical_accuracy: 1.0000
# Epoch 8/15
# 94/94 [==============================] - 24s 256ms/step - loss: 0.0094 - acc: 0.9987 - top_k_categorical_accuracy: 1.0000 - val_loss: 0.0600 - val_acc: 0.9813 - val_top_k_categorical_accuracy: 0.9987
# Epoch 9/15
# 94/94 [==============================] - 24s 258ms/step - loss: 0.0063 - acc: 0.9987 - top_k_categorical_accuracy: 1.0000 - val_loss: 0.0413 - val_acc: 0.9893 - val_top_k_categorical_accuracy: 1.0000
# Epoch 10/15
# 94/94 [==============================] - 24s 257ms/step - loss: 0.0037 - acc: 1.0000 - top_k_categorical_accuracy: 1.0000 - val_loss: 0.0284 - val_acc: 0.9946 - val_top_k_categorical_accuracy: 1.0000
# Epoch 11/15
# 94/94 [==============================] - 24s 259ms/step - loss: 0.0030 - acc: 0.9987 - top_k_categorical_accuracy: 1.0000 - val_loss: 0.0603 - val_acc: 0.9853 - val_top_k_categorical_accuracy: 0.9987
# Epoch 12/15
# 94/94 [==============================] - 24s 258ms/step - loss: 0.0066 - acc: 0.9960 - top_k_categorical_accuracy: 1.0000 - val_loss: 0.1737 - val_acc: 0.9692 - val_top_k_categorical_accuracy: 1.0000
# Epoch 13/15
# 94/94 [==============================] - 24s 259ms/step - loss: 0.0047 - acc: 0.9987 - top_k_categorical_accuracy: 1.0000 - val_loss: 0.1150 - val_acc: 0.9799 - val_top_k_categorical_accuracy: 0.9987
# Epoch 14/15
# 94/94 [==============================] - 24s 259ms/step - loss: 0.0092 - acc: 0.9960 - top_k_categorical_accuracy: 1.0000 - val_loss: 0.3745 - val_acc: 0.9277 - val_top_k_categorical_accuracy: 0.9987
# Epoch 15/15
# 94/94 [==============================] - 25s 262ms/step - loss: 0.0124 - acc: 0.9947 - top_k_categorical_accuracy: 1.0000 - val_loss: 0.1403 - val_acc: 0.9531 - val_top_k_categorical_accuracy: 0.9973

# %%
# save the model to disk
model.save("E:\models\ResNet50-dataset15-d299-e15")

# %%
# save the label binarizer to disk
f = open(r"E:\models\lb-dataset15-r", "wb")
f.write(pickle.dumps(lb))
f.close()
